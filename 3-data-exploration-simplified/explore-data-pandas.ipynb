# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
dataflair = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv", sep=",")
dataflair.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
dataflair.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
dataflair.shape
# Out:
# (17000, 9)

# %%
dataflair["households"].hist()
plt.show()

# %%
for column in dataflair.select_dtypes(exclude=['object']).columns:
    hist = dataflair[column].hist()
    print(column)
    plt.show()
# Out:
# longitude
# latitude
# housing_median_age
# total_rooms
# total_bedrooms
# population
# households
# median_income
# median_house_value

# %%
x = dataflair[dataflair.columns[0:4]].corr()

# %%
pd.plotting.scatter_matrix(x , figsize=(12, 12))
plt.show()

# %%
dataflair.plot.line(x='longitude', y='population', figsize=(8,6))
plt.show()

# %%
dataflair.boxplot(column=['population', 'households'], figsize=(8,6))
plt.show()

# %%
dataflair["median_income"].plot.kde()
plt.show()

# %%
dataflair.plot.scatter(x='housing_median_age', y='median_income', figsize=(8,6))
plt.show()

# %%
dataflair.plot.hexbin(x='longitude', y='median_income',gridsize=30, figsize=(8,6))
plt.show()

# %%
df = pd.DataFrame({'mass': [0.330, 4.87 , 5.97],'radius': [2439.7, 6051.8, 6378.1]},index=['Mercury', 'Venus', 'Earth'])
df.plot.pie(y='mass', figsize=(5, 5))
plt.show()

# %%
df.plot.pie(subplots=True, figsize=(6, 3))
plt.show()

# %%
#x = dataflair.corr()

# %%
dataflair.corr()['latitude']
# Out:
# longitude            -0.925208
# latitude              1.000000
# housing_median_age    0.016454
# total_rooms          -0.038773
# total_bedrooms       -0.069373
# population           -0.111261
# households           -0.074902
# median_income        -0.080303
# median_house_value   -0.144917
# Name: latitude, dtype: float64

# %%
# Your data should be a pandas dataframe for this example
import pandas
corr_matrix = dataflair.corr()
x = corr_matrix["latitude"].sort_values(ascending=False)

x
# Out:
# latitude              1.000000
# housing_median_age    0.016454
# total_rooms          -0.038773
# total_bedrooms       -0.069373
# households           -0.074902
# median_income        -0.080303
# population           -0.111261
# median_house_value   -0.144917
# longitude            -0.925208
# Name: latitude, dtype: float64

# %%
x.plot.line()
plt.autoscale
plt.title("Latitude as traget to rest of features correlation")
plt.xticks(rotation=45)
plt.show()
